# %% [markdown]
# # Business statement
#
#
#     forecasting the rainfall

# %% [markdown]
# # data collecting
#
#     Australia Rainfall Dataset Collected from Kaggle

# %% [markdown]
# # Required Modules

# %%
import pandas as pd    # for manipulation
import numpy as np      # multi dimensional calucluations
from datetime import datetime  # to coverty object datatype to datetime format


from sklearn.preprocessing import LabelEncoder  # adding label to the dataset values - not binary enoder

import matplotlib.pyplot as plt  # plotting the data
import seaborn as sns    # 
# %matplotlib inline


import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Lenovo\\A_shashikala Mam'

# %% [markdown]
# # loading Dataset

# %%
# where rf - rain fall

rf = pd.read_csv('AUS_rf.csv')

# %% [markdown]
# # Total Dataset size
#
#
#     shape will return the rows and colums of given dataframe

# %%
print("Shape of Dataset :",rf.shape)
print("Total No of recoreds : ",rf.shape[0])
print("Toal No of Columns : ",rf.shape[1])
# Out:
# Shape of Dataset : (145460, 23)
# Total No of recoreds :  145460
# Toal No of Columns :  23

# %% [markdown]
# # Columns Name

# %%
rf.columns
# Out:
# Index(['Date', 'Location', 'MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation',
#        'Sunshine', 'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RainTomorrow'],
#       dtype='object')

# %% [markdown]
# # Sample 5 records from Dataset

# %%
rf.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %% [markdown]
# # Description of Dataset

# %%
rf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           145460 non-null  object
#  1   Location       145460 non-null  object
#  2   MinTemp        143975 non-null  float64
#  3   MaxTemp        144199 non-null  float64
#  4   Rainfall       142199 non-null  float64
#  5   Evaporation    82670 non-null   float64
#  6   Sunshine       75625 non-null   float64
#  7   WindGustDir    135134 non-null  object
#  8   WindGustSpeed  135197 non-null  float64
#  9   WindDir9am     134894 non-null  object
#  10  WindDir3pm     141232 non-null  object
#  11  WindSpeed9am   143693 non-null  float64
#  12  WindSpeed3pm   142398 non-null  float64
#  13  Humidity9am    142806 non-null  float64
#  14  Humidity3pm    140953 non-null  float64
#  15  Pressure9am    130395 non-null  float64
# ...

# %% [markdown]
# # Analysis of Above Results
#
#     1. Total No of records are : 145460
#
#         Except Data and Time , remaining all columns contain Null values

# %% [markdown]
# # Step - 2:
#
#
#     min, max, avg, firstquartile , halfquartile, 3rd qulitile resulats

# %%
rf.describe()
# Out:
#              MinTemp        MaxTemp       Rainfall   Evaporation  \
# count  143975.000000  144199.000000  142199.000000  82670.000000
# mean       12.194034      23.221348       2.360918      5.468232
# std         6.398495       7.119049       8.478060      4.193704
# min        -8.500000      -4.800000       0.000000      0.000000
# 25%         7.600000      17.900000       0.000000      2.600000
# 50%        12.000000      22.600000       0.000000      4.800000
# 75%        16.900000      28.200000       0.800000      7.400000
# max        33.900000      48.100000     371.000000    145.000000
#
#            Sunshine  WindGustSpeed   WindSpeed9am   WindSpeed3pm  \
# count  75625.000000  135197.000000  143693.000000  142398.000000
# mean       7.611178      40.035230      14.043426      18.662657
# std        3.785483      13.607062       8.915375       8.809800
# min        0.000000       6.000000       0.000000       0.000000
# ...

# %%
rf.isnull().mean()*100
# Out:
# Date              0.000000
# Location          0.000000
# MinTemp           1.020899
# MaxTemp           0.866905
# Rainfall          2.241853
# Evaporation      43.166506
# Sunshine         48.009762
# WindGustDir       7.098859
# WindGustSpeed     7.055548
# WindDir9am        7.263853
# WindDir3pm        2.906641
# WindSpeed9am      1.214767
# WindSpeed3pm      2.105046
# Humidity9am       1.824557
# Humidity3pm       3.098446
# Pressure9am      10.356799
# Pressure3pm      10.331363
# Cloud9am         38.421559
# Cloud3pm         40.807095
# Temp9am           1.214767
# Temp3pm           2.481094
# RainToday         2.241853
# RainTomorrow      2.245978
# dtype: float64

# %% [markdown]
#         Here we are seeing that, there are four features which contains around (45-50)% of missing value. And we cann't also just delete them, because those could greatly impact in our modeling.So Our first task is to check this then start proceding

# %% [markdown]
# # Collecting only relavent values from the Main dataset

# %%
Miss_tar = rf[['Evaporation', 'Sunshine', 'Cloud9am','Cloud3pm','RainTomorrow']]

# %%
type(Miss_tar)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # Replacing the "Null" vlaue to "No" - of  RainTomorrow column

# %%
Miss_tar['RainTomorrow'].fillna(value="No", inplace=True)
# Out:
# E:\anaconda_1\lib\site-packages\pandas\core\series.py:4463: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
Miss_tar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145460 entries, 0 to 145459
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Evaporation   82670 non-null   float64
#  1   Sunshine      75625 non-null   float64
#  2   Cloud9am      89572 non-null   float64
#  3   Cloud3pm      86102 non-null   float64
#  4   RainTomorrow  145460 non-null  object
# dtypes: float64(4), object(1)
# memory usage: 5.5+ MB

# %%
Miss_tar
# Out:
#         Evaporation  Sunshine  Cloud9am  Cloud3pm RainTomorrow
# 0               NaN       NaN       8.0       NaN           No
# 1               NaN       NaN       NaN       NaN           No
# 2               NaN       NaN       NaN       2.0           No
# 3               NaN       NaN       NaN       NaN           No
# 4               NaN       NaN       7.0       8.0           No
# ...             ...       ...       ...       ...          ...
# 145455          NaN       NaN       NaN       NaN           No
# 145456          NaN       NaN       NaN       NaN           No
# 145457          NaN       NaN       NaN       NaN           No
# 145458          NaN       NaN       3.0       2.0           No
# 145459          NaN       NaN       8.0       8.0           No
#
# [145460 rows x 5 columns]

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
Miss_tar['RainTomorrow'] = le.fit_transform(Miss_tar['RainTomorrow'])
# Out:
# <ipython-input-153-04f7796c08e4>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Miss_tar['RainTomorrow'] = le.fit_transform(Miss_tar['RainTomorrow'])

# %%
sns.heatmap(Miss_tar.corr(), cmap = 'RdBu', annot = True, linewidths=1, linecolor='black')
# Out:
# <AxesSubplot:>

# %% [markdown]
#         Here we are seeing that Cloud9am and Cloud3pm are roughly releated to our target variable and there is a good relationship between them also.And rest two are badly related with target and between themselves also. So let's go with this two and let's see...

# %% [markdown]
# # relacing the Cloud9am & Cloud3pm with mean

# %%
rf = rf.drop(['Evaporation','Sunshine'], axis = 1)
rf['Cloud9am'] = rf.Cloud9am.mean()
rf['Cloud3pm'] = rf.Cloud3pm.mean()
rf.dropna(inplace = True)
np.round(rf.isnull().mean())
# Out:
# Date             0.0
# Location         0.0
# MinTemp          0.0
# MaxTemp          0.0
# Rainfall         0.0
# WindGustDir      0.0
# WindGustSpeed    0.0
# WindDir9am       0.0
# WindDir3pm       0.0
# WindSpeed9am     0.0
# WindSpeed3pm     0.0
# Humidity9am      0.0
# Humidity3pm      0.0
# Pressure9am      0.0
# Pressure3pm      0.0
# Cloud9am         0.0
# Cloud3pm         0.0
# Temp9am          0.0
# Temp3pm          0.0
# RainToday        0.0
# RainTomorrow     0.0
# dtype: float64

# %%
rf.columns
# Out:
# Index(['Date', 'Location', 'MinTemp', 'MaxTemp', 'Rainfall', 'WindGustDir',
#        'WindGustSpeed', 'WindDir9am', 'WindDir3pm', 'WindSpeed9am',
#        'WindSpeed3pm', 'Humidity9am', 'Humidity3pm', 'Pressure9am',
#        'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am', 'Temp3pm',
#        'RainToday', 'RainTomorrow'],
#       dtype='object')

# %% [markdown]
# # Let's have look at our variable
#     Variable Types
#
#     Numerical variables: 'MinTemp', 'MaxTemp', 'Rainfall','WindGustSpeed','WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm', 'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am', 'Temp3pm',
#
#     Categorical variables: 'Date', 'Location','WindGustDir','WindDir9am','WindDir3pm','RainToday', 'RainTomorrow'

# %%
numerical = [var for var in rf.columns if rf[var].dtype!='O']

print('There are {} numerical variables\n'.format(len(numerical)))

print('The numerical variables are :', numerical)

rf_num = rf[numerical]
# Out:
# There are 14 numerical variables
#
# The numerical variables are : ['MinTemp', 'MaxTemp', 'Rainfall', 'WindGustSpeed', 'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm', 'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am', 'Temp3pm']

# %%
categorical = [var for var in rf.columns if rf[var].dtype=='O']

print('There are {} numerical variables\n'.format(len(categorical)))

print('The numerical variables are :', categorical)
rf_cat = rf[categorical]
# Out:
# There are 7 numerical variables
#
# The numerical variables are : ['Date', 'Location', 'WindGustDir', 'WindDir9am', 'WindDir3pm', 'RainToday', 'RainTomorrow']

# %% [markdown]
# # Let's Analyse the data :
#
#     Let's start with spliting the date colimn into year, month and day

# %%
#first convert this 'date' column into datetime type

rf['Date'] = pd.to_datetime(rf['Date'])

# %%
#split date 

rf['Year'] = rf['Date'].dt.year
rf['Quarter'] = rf['Date'].dt.quarter
rf['Month'] = rf['Date'].dt.month
rf['Weakday'] = rf['Date'].dt.weekday
rf['Day'] = rf['Date'].dt.day

# %%
#Setting Date column as index
rf = rf.set_index('Date')

# %% [markdown]
# # before dig deep into time series analysis let's see how rain occurs with respect to Year

# %%
sns.set_style('darkgrid')
#sns.set_palette('Set1')
plt.figure(figsize=[15,6])
ax = sns.countplot(x = 'Year', hue = 'RainTomorrow',edgecolor=(0,0,0),linewidth=2,palette="Accent_r", data = rf)
ax.set_title( "Occurence of rain in Years",size = 30 )
plt.show()

# %% [markdown]
# Here we are seeing a seasonality.From a Certain year Rain starts increasing and after 3-4 years it's reaches to pick and start decreasing.........

# %%
sns.set_style('darkgrid')
sns.set_palette('Set2')
plt.figure(figsize=[15,6])
ax = sns.scatterplot(x = 'Month', y = 'Rainfall',data = rf)
ax.set_title( "Amount of  rain in Month",size = 30 )
plt.show()

# %%
sns.set_style('darkgrid')
sns.set_palette('spring_r')
plt.figure(figsize=[15,6])
ax = sns.countplot(x = 'Day', hue = 'RainTomorrow',edgecolor=(0,0,0),linewidth=2,data = rf)
ax.set_title( "Occurence of rain in day of month",size = 30 )
plt.show()

# %%
sns.set_style('darkgrid')
sns.set_palette('plasma')
plt.figure(figsize=[15,6])
ax = sns.scatterplot(x = 'Day', y = 'Rainfall',data = rf)
ax.set_title( "Amount of rain in day of month",size = 30 )
plt.show()

# %%
sns.set_style('darkgrid')
sns.set_palette('plasma_r')
plt.figure(figsize=[15,6])
ax = sns.countplot(x = 'Quarter', hue = 'RainTomorrow',edgecolor=(0,.78,1),linewidth=3,data = rf)
ax.set_title( "Occurence of rain in Quarter",size = 30 )
plt.show()

# %% [markdown]
# # Temparature

# %%
#Let's make new column to check how temp is changing.
rf['Temp_diff'] = rf['Temp3pm'] - rf['Temp9am']

# %%
fig = plt.figure()
x = (rf[['MaxTemp','Temp_diff','Rainfall','WindGustSpeed']])
x.plot(grid =True, subplots = True,figsize = (50,30), fontsize = 50, legend = 'reverse')
#title = 'How Numerical value changes with respect to time '
#fig.suptitle = 'Temparature vs Rainfall Vs WindGustSpeed'
plt.grid()
plt.show()
